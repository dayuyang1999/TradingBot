# %%
from datetime import datetime, timedelta

from tqdm import tqdm
from pytz import timezone
############################## create api /

from alpaca_trade_api.rest import REST, TimeFrame
from alpaca_trade_api.stream import Stream

import alpaca_trade_api as tradeapi

import numpy as np

# %%
from TradingBot.utils.data import get_data

# %%
from TradingBot.strategy.backtest import RollingBackTest, APISettings, BackTest
import matplotlib.pyplot as plt

# %%
nyc = timezone('America/New_York')
now = datetime.today().astimezone(nyc)
today_str = datetime.today()+ timedelta(1)
today_str = today_str.astimezone(nyc).strftime('%Y-%m-%d')

# %%
print(today_str)
# Out:
# 2022-10-08

# %% [markdown]
# # Rolling

# %% [markdown]
# ## 1min

# %%
# 1min only for recent 29days

days_before = datetime.today() - timedelta(29)   # 1min, max = 29
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
start_testing_date = data_start_date
testing_length = 2
gap=1

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 2
    long_sell_thres = 2
    short_buy_thres = 2
    short_sell_thres = 2
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum
    

rollingbacktest = RollingBackTest(
    Momentum_settings(),APISettings(),'momentum',start_testing_date,testing_length,
    '^IXIC','TQQQ','SQQQ',
    '1m',gap,False,False
)

#print(rollingbacktest.total_rets, '\n')

#print(rollingbacktest.rets_noncomp, '\n')


print('mean of cumulated ret: ', np.mean(rollingbacktest.total_rets), '\n')

print('mean of non-cumulated ret: ', np.mean(rollingbacktest.rets_noncomp), '\n')

plt.plot(rollingbacktest.total_rets)
plt.axhline(y=1, color='r', linestyle='-')
#plt.ylim(0.8, 1.2)
# Out:
# start testing...
# 100%|██████████| 19/19 [00:10<00:00,  1.81it/s]
# mean of cumulated ret:  1.0338202995184442
#
# mean of non-cumulated ret:  1.000023239427991

# %%
# 1min only for recent 29days

days_before = datetime.today() - timedelta(29)   # 1min, max = 29
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
start_testing_date = data_start_date
testing_length = 2
gap=1

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 5
    long_sell_thres = 5
    short_buy_thres = 5
    short_sell_thres = 5
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum
    

rollingbacktest = RollingBackTest(
    Momentum_settings(),APISettings(),'momentum',start_testing_date,testing_length,
    '^IXIC','TQQQ','SQQQ',
    '1m',gap,False,False
)

#print(rollingbacktest.total_rets, '\n')

#print(rollingbacktest.rets_noncomp, '\n')


print('mean of cumulated ret: ', np.mean(rollingbacktest.total_rets), '\n')

print('mean of non-cumulated ret: ', np.mean(rollingbacktest.rets_noncomp), '\n')

plt.plot(rollingbacktest.total_rets)
plt.axhline(y=1, color='r', linestyle='-')
#plt.ylim(0.8, 1.2)
# Out:
# start testing...
# 100%|██████████| 19/19 [00:10<00:00,  1.84it/s]
# mean of cumulated ret:  1.0260803693160456
#
# mean of non-cumulated ret:  1.0000166547222373

# %% [markdown]
# ## 5minites

# %%
# 5min only for recent 60days

days_before = datetime.today() - timedelta(59)   # 5min, max = 59
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
start_testing_date = data_start_date
testing_length = 5
gap=1

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 5
    long_sell_thres = 5
    short_buy_thres = 5
    short_sell_thres = 5
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum
    

rollingbacktest = RollingBackTest(
    Momentum_settings(),
    APISettings(),
    'momentum',
    start_testing_date,
    testing_length,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '5m',
    gap,
    False,
    True
)

print(rollingbacktest.total_rets, '\n')

#print(rollingbacktest.rets_noncomp, '\n')


print('mean of cumulated ret: ', np.mean(rollingbacktest.total_rets), '\n')

print('mean of non-cumulated ret: ', np.mean(rollingbacktest.rets_noncomp), '\n')

plt.plot(rollingbacktest.total_rets)
plt.axhline(y=1, color='r', linestyle='-')
#plt.ylim(0.8, 1.2)
# Out:
# start testing...
# 100%|██████████| 38/38 [00:14<00:00,  2.60it/s]
# [1.0705382716243448, 1.0065999343238108, 0.9867850219858167, 0.98964322257827, 0.9860205673598815, 1.0116123976811988, 1.0847800894673685, 1.0741608227218888, 1.0346164775512405, 1.0163561757801804, 0.9592616781006064, 0.9307225522231478, 0.9527978122499761, 0.9989860368520808, 1.0025543835912856, 0.978711293630952, 1.082030615071593, 1.1075046862347548, 1.1013772936655066, 1.0568912895147784, 1.04437231328299, 1.0556494112299002, 1.0232656407118665, 1.0975264987796824, 1.0792175633195937, 1.0560111245684143, 1.017598852067893, 0.97396079434732, 0.9760447115411689, 0.9129484766827413, 1.017619593671353, 1.0086390369695344, 1.0032916670129308, 0.9738092590192372, 1.0290633066928283, 1.1230773484228065, 1.0747974569911127, 1.0755513692818852]
#
# mean of cumulated ret:  1.0256419749158403
#
# mean of non-cumulated ret:  1.000047629092872

# %% [markdown]
# ## 15min

# %%
# 15min only for recent 60days

days_before = datetime.today() - timedelta(59)  # max 60
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
start_testing_date = data_start_date
testing_length = 10
gap=1

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 5
    long_sell_thres = 5
    short_buy_thres = 5
    short_sell_thres = 5
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 2 # price smooth factor for computing momentum
    

rollingbacktest = RollingBackTest(
    Momentum_settings(),
    APISettings(),
    'momentum',
    start_testing_date,
    testing_length,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '15m',
    gap,
    False
)

print(rollingbacktest.total_rets, '\n')

print(rollingbacktest.rets_noncomp, '\n')

print('mean of acumulated ret: ', np.mean(rollingbacktest.total_rets), '\n')

print(np.mean(rollingbacktest.rets_noncomp), '\n')

plt.plot(rollingbacktest.total_rets)
plt.axhline(y=1, color='r', linestyle='-')
plt.ylim(0.8,2.5)
# Out:
# start testing...
# 100%|██████████| 34/34 [00:07<00:00,  4.47it/s]
# [0.9147196204663394, 0.965330248601364, 0.9438781422397674, 0.9807333259821412, 0.9586284947357742, 0.8956615257717734, 0.9772949841592472, 1.0297671792122054, 1.019945850054098, 0.9903766747471063, 1.043900082920018, 1.0529469994447096, 1.1688912042193111, 1.1934732525377052, 1.1743774153770365, 1.0903749019775908, 1.0032476253846634, 1.0573775674438914, 1.0124563301228835, 1.0550345393272464, 0.9183200232190601, 0.935359087171727, 0.956453233224667, 1.0176651799053933, 1.0385070177672535, 0.9614962014595573, 0.9425161129629297, 0.9448240811877695, 0.9349631628094132, 0.7406606293072177, 0.8209031411539469, 0.7866152995561587, 0.791224292793865, 0.7766800417981903]
#
# [0.9998002252631039, 0.9999283546390817, 0.9998737477167283, 0.9999625649715984, 0.9998802114603719, 0.9997477418970436, 0.9999501292330423, 1.0000761847585449, 1.0000600474349253, 0.9999738923096112, 1.000110985915824, 1.0001315301892908, 1.000381900971328, 1.00049302816334, 1.0005227958965555, 1.0002163194502651, 1.0000198148283514, 1.0001476355278411, 1.0000494388611925, 1.000190480467253, 0.9997809902524644, 0.9998317969870493, 0.9998921637282048, 1.0000680627001852, 1.000156922318406, 0.999924828321491, 0.9998758276716463, 0.9998642073446903, 0.9998063598711222, 0.9993072030667203, 0.9995465735698458, 0.999446784212634, 0.9993812597145126, 0.9992166306418103]
#
# mean of acumulated ret:  0.9733706902659418
#
# 0.9999299011869435
# (0.8, 2.5)

# %% [markdown]
# ## 30min

# %%
days_before = datetime.today() - timedelta(59) 
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
start_testing_date = data_start_date
testing_length = 10
gap = 2

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 10
    long_sell_thres = 10
    short_buy_thres = 10
    short_sell_thres = 10
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum
 
rollingbacktest = RollingBackTest(
    Momentum_settings(),
    APISettings(),
    'momentum',
    start_testing_date,
    testing_length,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '30m',
    gap,
    False
)

#print(rollingbacktest.total_rets, '\n')

#print(rollingbacktest.rets_noncomp, '\n')

print(np.mean(rollingbacktest.total_rets), '\n')

print(np.mean(rollingbacktest.rets_noncomp), '\n')

plt.plot(rollingbacktest.total_rets)
plt.axhline(y=1, color='r', linestyle='-')
# Out:
# start testing...
# 100%|██████████| 17/17 [00:04<00:00,  3.78it/s]
# 1.0051881942133114
#
# 1.0000515515228905

# %% [markdown]
# ## 1h

# %%
days_before = datetime.today() - timedelta(500)  # max 60days
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
start_testing_date = data_start_date
testing_length = 50
gap = 5

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 10
    long_sell_thres = 10
    short_buy_thres = 10
    short_sell_thres = 10
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum
 
rollingbacktest = RollingBackTest(
    Momentum_settings(),
    APISettings(),
    'momentum',
    start_testing_date,
    testing_length,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '1h',
    gap,
    False,
    False
)

#print(rollingbacktest.total_rets, '\n')

#print(rollingbacktest.rets_noncomp, '\n')

print(np.mean(rollingbacktest.total_rets), '\n')

print(np.mean(rollingbacktest.rets_noncomp), '\n')

plt.plot(rollingbacktest.total_rets)
plt.axhline(y=1, color='r', linestyle='-')
# Out:
# start testing...
# 100%|██████████| 62/62 [00:14<00:00,  4.23it/s]
# 1.1157626909748586
#
# 1.0002450551006803

# %% [markdown]
# ## Daily

# %%
days_before = datetime.today() - timedelta(1000)  # max 60days
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
start_testing_date = data_start_date
testing_length = 100
gap = 10


class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 10
    long_sell_thres = 10
    short_buy_thres = 10
    short_sell_thres = 10
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum

rollingbacktest = RollingBackTest(
    Momentum_settings(),
    APISettings(),
    'momentum',
    start_testing_date,
    testing_length,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '1d',
    gap,
    False
)

# print(rollingbacktest.total_rets, '\n')

# print(rollingbacktest.rets_noncomp, '\n')

print(np.mean(rollingbacktest.total_rets), '\n')

print(np.mean(rollingbacktest.rets_noncomp), '\n')

plt.plot(rollingbacktest.total_rets)
plt.axhline(y=1, color='r', linestyle='-')
# Out:
# start testing...
# 100%|██████████| 63/63 [00:13<00:00,  4.68it/s]
# 1.0099382671055814
#
# 1.0004454533035099

# %% [markdown]
# # Non-rolling test

# %% [markdown]
# ## 1min

# %%
days_before = datetime.today() - timedelta(1)  # if consistant. length should <7
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 2
    long_sell_thres = 2
    short_buy_thres = 2
    short_sell_thres = 2
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 4 # price smooth factor for computing momentum


back_test = BackTest(
    'momentum',
    Momentum_settings(),
    data_start_date,
    today_str,
    # data_start_date,
    # today_str,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '1m',
    'Close'
)


print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.4880952380952381 0.44029850746268656 0.5198019801980198
# 1.0657595829265993 1.0797504826646938 0.987042469568

# %%
plt.plot(back_test.totals)

# %%
# actually earn

# %%
days_before = datetime.today() - timedelta(1)  # if consistant. length should <7
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 2
    long_sell_thres = 2
    short_buy_thres = 2
    short_sell_thres = 2
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 5 # price smooth factor for computing momentum


back_test = BackTest(
    'momentum',
    Momentum_settings(),
    data_start_date,
    today_str,
    # data_start_date,
    # today_str,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '1m',
    'Close'
)


print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.4899135446685879 0.4891304347826087 0.49079754601226994
# 1.055097733485779 1.0269973389854028 1.0273617013731866

# %%
plt.plot(back_test.totals)

# %% [markdown]
# ## 1min QLD QID

# %%
days_before = datetime.today() - timedelta(6)  # if consistant. length should <7
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 2
    long_sell_thres = 2
    short_buy_thres = 2
    short_sell_thres = 2
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum


back_test = BackTest(
    'momentum',
    Momentum_settings(),
    data_start_date,
    today_str,
    # data_start_date,
    # today_str,
    '^IXIC',
    'QLD',
    'QID',
    '1m',
    'Close'
)


print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.5063965884861408 0.49469214437367304 0.5182012847965739
# 1.0620467359384358 1.0452625957171655 1.016057343188249

# %%
plt.plot(back_test.totals)

# %% [markdown]
# ## 5min

# %%
days_before = datetime.today() - timedelta(10) 
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 5
    long_sell_thres = 5
    short_buy_thres = 5
    short_sell_thres = 5
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum


back_test = BackTest(
    'momentum',
    Momentum_settings(),
    # '2022-08-05',
    # '2022-08-10',
    data_start_date,
    today_str,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '5m',
    'Close'
)


print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.5330578512396694 0.5271317829457365 0.5398230088495575
# 1.0974556146603185 0.9867707290753004 1.1121687969896923

# %%
plt.plot(back_test.totals)

# %%
days_before = datetime.today() - timedelta(59)  # max = 59
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 5
    long_sell_thres = 5
    short_buy_thres = 5
    short_sell_thres = 5
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum


back_test = BackTest(
    'momentum',
    Momentum_settings(),
    # '2022-08-05',
    # '2022-08-10',
    data_start_date,
    today_str,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '5m',
    'Close'
)


print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.49927113702623904 0.48854961832061067 0.5090655509065551
# 1.4371540114626202 1.3259456992387482 1.0838709400299869

# %% [markdown]
# ## 15 minitues

# %%
# %matplotlib inline
import time
from IPython.display import clear_output
import pylab as pl
from IPython import display

# %%
days_before = datetime.today() - timedelta(30) 
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')
class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 5
    long_sell_thres = 5
    short_buy_thres = 5
    short_sell_thres = 5
    ema_smooth_factor = 20 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum


back_test = BackTest(
    'momentum',
    Momentum_settings(),
    data_start_date,
    today_str,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '15m',
    'Close'
)

print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_short, back_test.return_long)
# Out:
# 0.4797136038186158 0.46296296296296297 0.490272373540856
# 0.9994351803249673 0.7945546715897555

# %%
print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_short, back_test.return_long)
# Out:
# 0.46798029556650245 0.4444444444444444 0.48360655737704916
# 1.0153884788921146 0.7681762336818576

# %%
plt.plot(back_test.totals)

# %%
plt.plot(np.sort(back_test.momentum.signal_df['dif']))

# %%
import seaborn as sns

# %%
sns.distplot(back_test.momentum.differentials, bins=100, color="g")
# Out:
# /home/dayu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
nyc = timezone('America/New_York')
days_before = datetime.today() - timedelta(6)
days_before_str = days_before.astimezone(nyc).strftime('%Y-%m-%d')

# %%
days_before_str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_524632/2775274889.py in <module>
# ----> 1 days_before_str
#
# NameError: name 'days_before_str' is not defined

# %% [markdown]
# ## 1h

# %%
# %matplotlib inline
import time
from IPython.display import clear_output
import pylab as pl
from IPython import display

# %% [markdown]
# Some rule:
# - short thres should be larger than long thres
#
# First, adjust dif smooth
# - dif smooth factor should be adjust first:
#   - if too small, so many distracting signal
#   - if too large, lag is large
# - ema smoother factor should be smaller...
#   - too large: lag is large: even if trend turned...
#   - too small:

# %%
#display.clear_output(wait=True)
days_before = datetime.today() - timedelta(50) 
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')


class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 10
    long_sell_thres = 10
    short_buy_thres = 10
    short_sell_thres = 10
    ema_smooth_factor = 60 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 3 # price smooth factor for computing momentum



back_test = BackTest(
    'momentum',
    Momentum_settings(),
    data_start_date,
    today_str,
    '^IXIC',
    'TQQQ',
    'SQQQ',
    '1h',
    'Close'
    
)


print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.5227272727272727 0.5789473684210527 0.5072463768115942
# 1.4722097072037628 1.5048306901773085 0.9783224895754205

# %%
print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.5227272727272727 0.5789473684210527 0.5072463768115942
# 1.4722097072037628 1.5048306901773085 0.9783224895754205

# %%
plt.plot(back_test.totals)

# %%
# while True:
#     display.clear_output(wait=True)
#     days_before = datetime.today() - timedelta(45) 
#     data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')

#     class Momentum_settings:
#         '''
#         if you found it is more likely to enter "long stage"
#             - you should set higher threshold for short, but lower threshold for long
#         '''
#         long_buy_thres = 0
#         long_sell_thres = 0
#         short_buy_thres = 0
#         short_sell_thres = 0
#         ema_smooth_factor = 8 # long-term indicator as ema smooth factor
#         # if larger, slower track of current price, more consistent
#         dif_smooth_factor = 16 # price smooth factor for computing momentum


#     back_test = BackTest(
#         'momentum',
#         Momentum_settings(),
#         data_start_date,
#         today_str,
#         '^IXIC',
#         'TQQQ',
#         'SQQQ',
#         '1h',
#         'Close'
        
#     )
    
#     display.display(pl.gcf())
#     time.sleep(20)

# %% [markdown]
# ## 1d

# %%
days_before = datetime.today() - timedelta(500) 
data_start_date = days_before.astimezone(nyc).strftime('%Y-%m-%d')

class Momentum_settings:
    '''
    if you found it is more likely to enter "long stage"
        - you should set higher threshold for short, but lower threshold for long
    '''
    long_buy_thres = 10
    long_sell_thres = 10
    short_buy_thres = 20
    short_sell_thres = 20
    ema_smooth_factor = 40 # long-term indicator as ema smooth factor
    # if larger, slower track of current price, more consistent
    dif_smooth_factor = 4 # price smooth factor for computing momentum


back_test = BackTest(
    'momentum',
    Momentum_settings(),
    data_start_date,
    today_str,
    '^IXIC',
    'TQQQ',
    'PSQ',
    '1d',
    'Close'
)


print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.5247933884297521 0.5772357723577236 0.47058823529411764
# 1.4848004441137723 1.102137898841869 1.3472002420695328

# %%
print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_total, back_test.return_short, back_test.return_long)
# Out:
# 0.5247933884297521 0.5772357723577236 0.47058823529411764
# 1.4848004441137723 1.102137898841869 1.3472002420695328

# %%
plt.plot(back_test.totals)

# %%
plt.plot(np.sort(back_test.momentum.differentials))

# %%
print(back_test.total_suc, back_test.long_suc, back_test.short_suc)
print(back_test.return_short, back_test.return_long)
# Out:
# 0.5202020202020202 0.5625 0.46511627906976744
# 0.9445358061935255 1.0197292406380647
